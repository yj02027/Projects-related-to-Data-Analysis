# %% [markdown]
# #  최적의 분산투자를 위한 종목 추천 모델링 ( Markowitz theory base )

# %% [markdown]
# ![image2](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FKjNDk%2FbtqGe7eRlE2%2Fdh3lNHSWh19C3PDPFLzxN0%2Fimg.png)

# %%
import FinanceDataReader as fdr #주식시계열 데이터 셋
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from itertools import combinations
import datetime
#plt.rcParams['font.family'] = 'AppleGothic' # mac OS
plt.rcParams['font.family'] = 'NanumGothic' # windows OS

# %%
df_krx = fdr.StockListing('KRX') #한국 주식 종목

# %%
df_krx[df_krx['Symbol'] == '005930'] # 종목코드로 검색하기
# Out:
#      Symbol Market  Name          Sector  \
# 954  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                               Industry ListingDate  \
# 954  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#     SettleMonth Representative              HomePage Region
# 954         12월  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도

# %%
endYear = datetime.datetime.now()

# %%
year = '20180504' # 시작 날짜
# endYear = '20200101' # 끝 날짜

# %%
def codeFinder(name): # 종목이름으로 종목코드 검색하는 함수
    search=list(df_krx['Name'])
    for i in range(len(df_krx)):
        if(search[i]==name):
            return df_krx['Symbol'][i]

# %%
topList = ['삼성전자',
            'SK하이닉스',
            'NAVER',
            '삼성바이오로직스',
            '현대차',
            '현대모비스',
            '셀트리온',
            'LG화학',
            'POSCO',
            '삼성물산',
            '신한지주',
            'KB금융',
            'LG생활건강',
            'SK텔레콤',
            'SK',
            '기아차',
            '한국전력',
            '삼성SDI',
            '삼성에스디에스',
            '삼성생명']

# %%
codeList = []
for i in topList:
    codeList.append(codeFinder(i))

# %% [markdown]
# 종목이름으로 종목코드 검색해서 리스트의 추가

# %%
samEle = fdr.DataReader(codeList[0],year,endYear)
skHyn = fdr.DataReader(codeList[1],year,endYear)
naver = fdr.DataReader(codeList[2],year,endYear)
samBio = fdr.DataReader(codeList[3],year,endYear)
hyunCar = fdr.DataReader(codeList[4],year,endYear)
hyunMob = fdr.DataReader(codeList[5],year,endYear)
Cell = fdr.DataReader(codeList[6],year,endYear)
LGche = fdr.DataReader(codeList[7],year,endYear)
POSCO = fdr.DataReader(codeList[8],year,endYear)
samMul = fdr.DataReader(codeList[9],year,endYear)
shin = fdr.DataReader(codeList[10],year,endYear)
KBG = fdr.DataReader(codeList[11],year,endYear)
LGlife = fdr.DataReader(codeList[12],year,endYear)
SKT = fdr.DataReader(codeList[13],year,endYear)
SK = fdr.DataReader(codeList[14],year,endYear)
KIA = fdr.DataReader(codeList[15],year,endYear)
KEPCO = fdr.DataReader(codeList[16],year,endYear)
samSDI = fdr.DataReader(codeList[17],year,endYear)
samSDS = fdr.DataReader(codeList[18],year,endYear)
samLife = fdr.DataReader(codeList[19],year,endYear)

# %%
tradingDaySum = len(samEle)

# %% [markdown]
# fdr.DataReader 를 통해 종목코드리스트를 인자로 받아 종목별 시계열 데이터생성

# %%
samEle.head(3)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2018-05-04  53000  53900  51800  51900  39565391 -0.020755
# 2018-05-08  52600  53200  51900  52600  23104720  0.013487
# 2018-05-09  52600  52800  50900  50900  16128305 -0.032319

# %%
closePrice = pd.concat([samEle.Close,
                        skHyn.Close,
                        naver.Close,
                        samBio.Close,
                        hyunCar.Close,
                        hyunMob.Close,
                        Cell.Close,
                        LGche.Close,
                        POSCO.Close,
                        samMul.Close,
                        shin.Close,
                        KBG.Close,
                        LGlife.Close,
                        SKT.Close,
                        SK.Close,
                        KIA.Close,
                        KEPCO.Close,
                        samSDI.Close,
                        samSDS.Close,
                        samLife.Close,
                        ],axis=1)

# %% [markdown]
# pd.concat 함수로 모든 종가데이터(Close)만 분리해서 하나로 합치기

# %%
closePrice.columns=topList # 칼럼이름을 위에 있던 topList로 대체

# %%
closePrice.head()
# Out:
#              삼성전자  SK하이닉스   NAVER  삼성바이오로직스     현대차   현대모비스    셀트리온    LG화학  \
# Date
# 2018-05-04  51900   83000  143604    359500  158000  235000  234597  341000
# 2018-05-08  52600   83500  146408    370500  156000  235000  221460  330500
# 2018-05-09  50900   83400  145607    398000  153500  235000  243042  339500
# 2018-05-10  51600   85800  144205    389500  152000  231500  243042  340000
# 2018-05-11  51300   86100  143604    386500  153000  237000  243981  345000
#
#              POSCO    삼성물산   신한지주   KB금융   LG생활건강   SK텔레콤      SK    기아차  \
# Date
# 2018-05-04  367500  128500  46800  59200  1304000  230500  299000  33750
# 2018-05-08  359000  127500  46950  58400  1293000  228000  299000  33850
# 2018-05-09  350500  129000  46700  58200  1331000  226000  295500  33550
# 2018-05-10  359500  127000  48000  58000  1309000  222500  297000  33450
# 2018-05-11  358000  129500  47700  58200  1313000  224500  304000  33900
#
#              한국전력   삼성SDI  삼성에스디에스    삼성생명
# Date
# 2018-05-04  37350  180500   218500  112500
# 2018-05-08  36750  184000   208500  112500
# 2018-05-09  35700  191000   218500  112000
# 2018-05-10  35900  190500   222000  112000
# 2018-05-11  35750  191000   223500  114500

# %%
(closePrice / closePrice.iloc[0] * 100).plot(figsize=(8, 5), grid=True)
plt.show()

# %%
change = pd.concat([samEle.Change,
                    skHyn.Change,
                    naver.Change,
                    samBio.Change,
                    hyunCar.Change,
                    hyunMob.Change,
                    Cell.Change,
                    LGche.Change,
                    POSCO.Change,
                    samMul.Change,
                    shin.Change,
                    KBG.Change,
                    LGlife.Change,
                    SKT.Change,
                    SK.Change,
                    KIA.Change,
                    KEPCO.Change,
                    samSDI.Change,
                    samSDS.Change,
                    samLife.Change,
                    ],axis=1)

# %% [markdown]
# pd.concat 함수로 모든 수익률 데이터(Change)만 때서 하나로 합치기

# %%
change.columns = topList # 컬럼이름을 topList로 대체

# %%
chageCov = change.cov() * tradingDaySum * 100 # 공분산행렬

# %%
chageCov.head()
# Out:
#                삼성전자     SK하이닉스      NAVER   삼성바이오로직스        현대차      현대모비스  \
# 삼성전자      17.345484  17.134415   6.875311   6.701181   9.773096  10.104515
# SK하이닉스    17.134415  31.714839   7.749822   6.354044  10.251642  10.378986
# NAVER      6.875311   7.749822  29.361293   8.476492   7.015028   7.998799
# 삼성바이오로직스   6.701181   6.354044   8.476492  54.821395   9.152510   7.769286
# 현대차        9.773096  10.251642   7.015028   9.152510  30.525356  23.078419
#
#                셀트리온       LG화학      POSCO       삼성물산       신한지주       KB금융  \
# 삼성전자       4.150046  11.280983   9.764286  10.921890   9.534012  10.230689
# SK하이닉스     7.866408  12.380994  10.596149  11.436866   9.715753  10.843782
# NAVER      7.861220  10.125977   5.163258   8.701985   4.504528   5.998629
# 삼성바이오로직스  23.693688  13.151107   5.612439  17.126419   4.906296   6.258609
# 현대차        8.104486  12.671906  12.548577  13.797788  13.419538  13.679201
#
#             LG생활건강     SK텔레콤         SK        기아차      한국전력      삼성SDI  \
# 삼성전자      6.896763  3.210235   9.955979   8.120510  3.845507  12.591640
# SK하이닉스    7.967484  2.530528  12.681622   9.000707  2.566556  16.006823
# NAVER     6.349928  2.528949  10.676612   5.505870  4.512501   9.164671
# 삼성바이오로직스  8.105592  2.410226  12.455792   7.330548  5.961200  15.917940
# 현대차       6.511183  5.201610  12.419147  21.920298  6.822698  11.318554
#
#            삼성에스디에스       삼성생명
# 삼성전자      8.713000   8.543196
# SK하이닉스    8.439941   9.261479
# NAVER     8.545291   5.028221
# 삼성바이오로직스  9.261895   7.728741
# 현대차       8.569615  15.925854

# %%
changeCorr = change.corr()

# %%
sns.heatmap(data=changeCorr,annot=True,fmt='.2f',linewidths=.5,cmap='Blues')

# %%
changeCorr.head()
# Out:
#               삼성전자    SK하이닉스     NAVER  삼성바이오로직스       현대차     현대모비스  \
# 삼성전자      1.000000  0.730541  0.304657  0.217312  0.424726  0.434376
# SK하이닉스    0.730541  1.000000  0.253964  0.152386  0.329482  0.329964
# NAVER     0.304657  0.253964  1.000000  0.211278  0.234321  0.264290
# 삼성바이오로직스  0.217312  0.152386  0.211278  1.000000  0.223735  0.187867
# 현대차       0.424726  0.329482  0.234321  0.223735  1.000000  0.747858
#
#               셀트리온      LG화학     POSCO      삼성물산      신한지주      KB금융  \
# 삼성전자      0.140821  0.430443  0.484591  0.560529  0.487865  0.473690
# SK하이닉스    0.197402  0.349371  0.388906  0.434079  0.367674  0.371306
# NAVER     0.205026  0.296969  0.196954  0.343261  0.177165  0.213475
# 삼성바이오로직스  0.452235  0.282260  0.156677  0.494407  0.141220  0.162999
# 현대차       0.207301  0.364480  0.469453  0.533793  0.517636  0.477434
#
#             LG생활건강     SK텔레콤        SK       기아차      한국전력     삼성SDI  \
# 삼성전자      0.320613  0.223605  0.386261  0.360554  0.194702  0.457743
# SK하이닉스    0.273917  0.130352  0.363859  0.295546  0.096101  0.430335
# NAVER     0.226887  0.135391  0.318373  0.187896  0.175606  0.256072
# 삼성바이오로직스  0.211953  0.094432  0.271823  0.183080  0.169773  0.325495
# 현대차       0.228170  0.273115  0.363204  0.733663  0.260397  0.310165
#
#            삼성에스디에스      삼성생명
# 삼성전자      0.431984  0.417891
# SK하이닉스    0.309458  0.335031
# NAVER     0.325636  0.189044
# 삼성바이오로직스  0.258296  0.212652
# 현대차       0.320276  0.587230

# %%
changeVar = (change.var() * tradingDaySum)

# %%
changeVar.head() # 연평균 변동폭
# Out:
# 삼성전자        0.173455
# SK하이닉스      0.317148
# NAVER       0.293613
# 삼성바이오로직스    0.548214
# 현대차         0.305254
# dtype: float64

# %%
def riskFun(assetA, assetB):
    """
    위험률 계산공식과 기대수익률 계산공식을 0.01 ~ 1 의 가중치를 가지고 X축(위험) Y축(기대수익률)의
    그래프를 그려주고 최저위험지점과 저위험고수익지점을 빨간색과 초록색지점으로 표시하고 그 값을 반환해주는 함수입니다.
    """
    corr = changeCorr.loc[assetA , assetB]
    
    if change[assetA].mean() > 0 and change[assetB].mean() > 0: 
        # A종목과 B 종목의 수익률 평균이 양수인 것들의 조합만 출력함 (나머지 종목도 다 계산됨)
        tempList = []
        for i in np.arange(1,100,1)/100:
            r_w1 = i
            r_w2 = 1-i
            temp = (r_w1**2) * changeVar[assetA] + (r_w2**2) * changeVar[assetB] + (2 * r_w1 * r_w2 * math.sqrt(changeVar[assetA] * changeVar[assetB]) * corr )
            tempList.append(temp)
            
        changeList = []
        for i in np.arange(1,100,1)/100:
            c_w1 = i
            c_w2 = 1-i
            temp = (change[assetA].mean() * tradingDaySum) * c_w1 + (change[assetB].mean() * tradingDaySum) * c_w2
            changeList.append(temp)
            
            
        #시각화
        g = sns.regplot(x=tempList, y=changeList,fit_reg=False)
        g.set_xlabel('위험률')
        g.set_ylabel('기대수익률')
        g.set_title('{} 와 {}'.format(assetA,assetB))
        
        #각각을 데이터프레임으로 합침
        df = pd.DataFrame(tempList)
        df['a'] = changeList
        df.columns = ['위험률','기대수익률']
        df['저위험고수익'] = df['기대수익률'] / df['위험률']
        
        
        minimizeRiskPercent = df[df['위험률']==df['위험률'].min()].index.values[0]
        minimizeRisk1 = df[df['위험률']==df['위험률'].min()].위험률.values[0]
        minimizeRisk2 = df[df['위험률']==df['위험률'].min()].기대수익률.values[0]
        plt.scatter(minimizeRisk1,minimizeRisk2,marker='*',s=500,alpha=0.5,color="red")
        #최저위험 지점 빨간색 별로 표시
        
        maxChangePercent = df[df['저위험고수익']==df['저위험고수익'].max()].index.values[0]
        maxChange1 = df[df['저위험고수익']==df['저위험고수익'].max()].위험률.values[0]
        maxChange2 = df[df['저위험고수익']==df['저위험고수익'].max()].기대수익률.values[0]
        plt.scatter(maxChange1,maxChange2,marker='*',s=500,alpha=0.5,color='green')
        #저위험고수익 지점 초록색 별로 표시
        plt.show()
        
        print('{} 종목과  {} 종목을 섞었을 경우 '.format(assetA,assetB))
        
        print("리스크가 가장 낮은 포트폴리오 비중은 : {} 종목 {}% 와 {} 종목 {}% 의 비중입니다.".format(assetA,minimizeRiskPercent,assetB,100-minimizeRiskPercent))
        print("리스크 지수 : {}이고".format(round(minimizeRisk1,2)))
        print("수익률 지수 : {}입니다".format(round(minimizeRisk2,2)))
        
        print()
        
        print("리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : {} 종목 {}% 와 {} 종목 {}% 의 비중입니다.".format(assetA,maxChangePercent,assetB,100-maxChangePercent))
        print("리스크 지수 : {}이고".format(round(maxChange1,2)))
        print("수익률 지수 : {}입니다".format(round(maxChange2,2)))
        return (assetA, assetB, minimizeRisk1 , maxChange2,minimizeRiskPercent,maxChangePercent)

# %% [markdown]
# ![image](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FXyq76%2FbtqGgwYWpT1%2FqdfqpYv6lP4gBKINKh0QnK%2Fimg.png)

# %% [markdown]
# ![image](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fbzc1kN%2FbtqGishxyI1%2F3J5uac8JvAFdEehrkkmtqk%2Fimg.png)

# %%
riskFun('삼성전자','NAVER')
# Out:
# 삼성전자 종목과  NAVER 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 67% 와 NAVER 종목 33% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.41입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 37% 와 NAVER 종목 63% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.63입니다
# ('삼성전자', 'NAVER', 0.14019283747845326, 0.6300287620068561, 67, 37)

# %%
topRank = []

# %%
mix = [] # A 종목과 B 종목의 중복을 제거한 한 쌍의 리스트들을 추가함
for i in combinations(topList , 2):
    mix.append(i)

# %%
mixA = []
mixB = [] 
for i in range(len(mix)): #한 쌍의 리스트를 하나하나씩 때어넴
    mixA.append(mix[i][0])
    mixB.append(mix[i][1])

# %%
for i in range(len(mixA)): # riskFun 함수를 통해 전체종목 조합을 돌리고 그 반환값을 topRank에 추가함.
    topRank.append(riskFun(mixA[i],mixB[i]))
# Out:
# 삼성전자 종목과  SK하이닉스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 98% 와 SK하이닉스 종목 2% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.18입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 98% 와 SK하이닉스 종목 2% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.18입니다
# 삼성전자 종목과  NAVER 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 67% 와 NAVER 종목 33% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.41입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 37% 와 NAVER 종목 63% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.63입니다
# 삼성전자 종목과  삼성바이오로직스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 81% 와 삼성바이오로직스 종목 19% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.33입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 56% 와 삼성바이오로직스 종목 44% 의 비중입니다.
# 리스크 지수 : 0.19이고
# 수익률 지수 : 0.53입니다
# 삼성전자 종목과  현대차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 72% 와 현대차 종목 28% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.2입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 61% 와 현대차 종목 39% 의 비중입니다.
# 리스크 지수 : 0.16이고
# 수익률 지수 : 0.21입니다
# 삼성전자 종목과  현대모비스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 73% 와 현대모비스 종목 27% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.17입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 78% 와 현대모비스 종목 22% 의 비중입니다.
# 리스크 지수 : 0.16이고
# 수익률 지수 : 0.17입니다
# 삼성전자 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 77% 와 셀트리온 종목 23% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.25입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 63% 와 셀트리온 종목 37% 의 비중입니다.
# 리스크 지수 : 0.16이고
# 수익률 지수 : 0.29입니다
# 삼성전자 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 81% 와 LG화학 종목 19% 의 비중입니다.
# 리스크 지수 : 0.16이고
# 수익률 지수 : 0.33입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 42% 와 LG화학 종목 58% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.64입니다
# 삼성전자 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 64% 와 LG생활건강 종목 36% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.23입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 51% 와 LG생활건강 종목 49% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.24입니다
# 삼성전자 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 37% 와 SK텔레콤 종목 63% 의 비중입니다.
# 리스크 지수 : 0.09이고
# 수익률 지수 : 0.12입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 51% 와 SK텔레콤 종목 49% 의 비중입니다.
# 리스크 지수 : 0.09이고
# 수익률 지수 : 0.13입니다
# 삼성전자 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 69% 와 기아차 종목 31% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.27입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 45% 와 기아차 종목 55% 의 비중입니다.
# 리스크 지수 : 0.16이고
# 수익률 지수 : 0.34입니다
# 삼성전자 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성전자 종목 86% 와 삼성SDI 종목 14% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.31입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성전자 종목 42% 와 삼성SDI 종목 58% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.73입니다
# SK하이닉스 종목과  NAVER 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 46% 와 NAVER 종목 54% 의 비중입니다.
# 리스크 지수 : 0.19이고
# 수익률 지수 : 0.55입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 21% 와 NAVER 종목 79% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.74입니다
# SK하이닉스 종목과  삼성바이오로직스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 65% 와 삼성바이오로직스 종목 35% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.43입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 40% 와 삼성바이오로직스 종목 60% 의 비중입니다.
# 리스크 지수 : 0.27이고
# 수익률 지수 : 0.64입니다
# SK하이닉스 종목과  현대차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 48% 와 현대차 종목 52% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.2입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 33% 와 현대차 종목 67% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.22입니다
# SK하이닉스 종목과  현대모비스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 48% 와 현대모비스 종목 52% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.14입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 46% 와 현대모비스 종목 54% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.14입니다
# SK하이닉스 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 63% 와 셀트리온 종목 37% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.27입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 42% 와 셀트리온 종목 58% 의 비중입니다.
# 리스크 지수 : 0.26이고
# 수익률 지수 : 0.34입니다
# SK하이닉스 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 57% 와 LG화학 종목 43% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.5입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 23% 와 LG화학 종목 77% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.79입니다
# SK하이닉스 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 43% 와 LG생활건강 종목 57% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.24입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 28% 와 LG생활건강 종목 72% 의 비중입니다.
# 리스크 지수 : 0.19이고
# 수익률 지수 : 0.26입니다
# SK하이닉스 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 23% 와 SK텔레콤 종목 77% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.1입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 30% 와 SK텔레콤 종목 70% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.1입니다
# SK하이닉스 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 46% 와 기아차 종목 54% 의 비중입니다.
# 리스크 지수 : 0.2이고
# 수익률 지수 : 0.32입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 24% 와 기아차 종목 76% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.39입니다
# SK하이닉스 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK하이닉스 종목 63% 와 삼성SDI 종목 37% 의 비중입니다.
# 리스크 지수 : 0.26이고
# 수익률 지수 : 0.5입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK하이닉스 종목 20% 와 삼성SDI 종목 80% 의 비중입니다.
# 리스크 지수 : 0.34이고
# 수익률 지수 : 0.93입니다
# NAVER 종목과  삼성바이오로직스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 68% 와 삼성바이오로직스 종목 32% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.93입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 66% 와 삼성바이오로직스 종목 34% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.94입니다
# NAVER 종목과  현대차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 50% 와 현대차 종목 50% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.59입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 70% 와 현대차 종목 30% 의 비중입니다.
# 리스크 지수 : 0.2이고
# 수익률 지수 : 0.72입니다
# NAVER 종목과  현대모비스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 51% 와 현대모비스 종목 49% 의 비중입니다.
# 리스크 지수 : 0.19이고
# 수익률 지수 : 0.54입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 76% 와 현대모비스 종목 24% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.73입니다
# NAVER 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 65% 와 셀트리온 종목 35% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.77입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 74% 와 셀트리온 종목 26% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.8입니다
# NAVER 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 60% 와 LG화학 종목 40% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.94입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 58% 와 LG화학 종목 42% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.94입니다
# NAVER 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 46% 와 LG생활건강 종목 54% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.59입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 64% 와 LG생활건강 종목 36% 의 비중입니다.
# 리스크 지수 : 0.19이고
# 수익률 지수 : 0.7입니다
# NAVER 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 25% 와 SK텔레콤 종목 75% 의 비중입니다.
# 리스크 지수 : 0.09이고
# 수익률 지수 : 0.3입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 51% 와 SK텔레콤 종목 49% 의 비중입니다.
# 리스크 지수 : 0.12이고
# 수익률 지수 : 0.51입니다
# NAVER 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 49% 와 기아차 종목 51% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.69입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 60% 와 기아차 종목 40% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.74입니다
# NAVER 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : NAVER 종목 62% 와 삼성SDI 종목 38% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 1.0입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : NAVER 종목 57% 와 삼성SDI 종목 43% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 1.01입니다
# 삼성바이오로직스 종목과  현대차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 31% 와 현대차 종목 69% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.5입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 53% 와 현대차 종목 47% 의 비중입니다.
# 리스크 지수 : 0.27이고
# 수익률 지수 : 0.66입니다
# 삼성바이오로직스 종목과  현대모비스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 32% 와 현대모비스 종목 68% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.43입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 58% 와 현대모비스 종목 42% 의 비중입니다.
# 리스크 지수 : 0.28이고
# 수익률 지수 : 0.65입니다
# 삼성바이오로직스 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 45% 와 셀트리온 종목 55% 의 비중입니다.
# 리스크 지수 : 0.38이고
# 수익률 지수 : 0.72입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 66% 와 셀트리온 종목 34% 의 비중입니다.
# 리스크 지수 : 0.41이고
# 수익률 지수 : 0.83입니다
# 삼성바이오로직스 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 38% 와 LG화학 종목 62% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.99입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 38% 와 LG화학 종목 62% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.99입니다
# 삼성바이오로직스 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 27% 와 LG생활건강 종목 73% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.5입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 47% 와 LG생활건강 종목 53% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.64입니다
# 삼성바이오로직스 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 14% 와 SK텔레콤 종목 86% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.22입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 38% 와 SK텔레콤 종목 62% 의 비중입니다.
# 리스크 지수 : 0.14이고
# 수익률 지수 : 0.44입니다
# 삼성바이오로직스 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 31% 와 기아차 종목 69% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.64입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 43% 와 기아차 종목 57% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.71입니다
# 삼성바이오로직스 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 삼성바이오로직스 종목 41% 와 삼성SDI 종목 59% 의 비중입니다.
# 리스크 지수 : 0.32이고
# 수익률 지수 : 1.08입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 삼성바이오로직스 종목 37% 와 삼성SDI 종목 63% 의 비중입니다.
# 리스크 지수 : 0.32이고
# 수익률 지수 : 1.09입니다
# 현대차 종목과  현대모비스 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 51% 와 현대모비스 종목 49% 의 비중입니다.
# 리스크 지수 : 0.27이고
# 수익률 지수 : 0.21입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 93% 와 현대모비스 종목 7% 의 비중입니다.
# 리스크 지수 : 0.3이고
# 수익률 지수 : 0.26입니다
# 현대차 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 64% 와 셀트리온 종목 36% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.34입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 53% 와 셀트리온 종목 47% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.37입니다
# 현대차 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 59% 와 LG화학 종목 41% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.55입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 30% 와 LG화학 종목 70% 의 비중입니다.
# 리스크 지수 : 0.27이고
# 수익률 지수 : 0.76입니다
# 현대차 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 45% 와 LG생활건강 종목 55% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.29입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 41% 와 LG생활건강 종목 59% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.29입니다
# 현대차 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 20% 와 SK텔레콤 종목 80% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.12입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 41% 와 SK텔레콤 종목 59% 의 비중입니다.
# 리스크 지수 : 0.12이고
# 수익률 지수 : 0.16입니다
# 현대차 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 45% 와 기아차 종목 55% 의 비중입니다.
# 리스크 지수 : 0.26이고
# 수익률 지수 : 0.38입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 4% 와 기아차 종목 96% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.47입니다
# 현대차 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대차 종목 62% 와 삼성SDI 종목 38% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.59입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대차 종목 34% 와 삼성SDI 종목 66% 의 비중입니다.
# 리스크 지수 : 0.27이고
# 수익률 지수 : 0.84입니다
# 현대모비스 종목과  셀트리온 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 63% 와 셀트리온 종목 37% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.27입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 44% 와 셀트리온 종목 56% 의 비중입니다.
# 리스크 지수 : 0.25이고
# 수익률 지수 : 0.34입니다
# 현대모비스 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 58% 와 LG화학 종목 42% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.49입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 24% 와 LG화학 종목 76% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.78입니다
# 현대모비스 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 44% 와 LG생활건강 종목 56% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.24입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 31% 와 LG생활건강 종목 69% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.26입니다
# 현대모비스 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 18% 와 SK텔레콤 종목 82% 의 비중입니다.
# 리스크 지수 : 0.11이고
# 수익률 지수 : 0.1입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 30% 와 SK텔레콤 종목 70% 의 비중입니다.
# 리스크 지수 : 0.11이고
# 수익률 지수 : 0.1입니다
# 현대모비스 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 43% 와 기아차 종목 57% 의 비중입니다.
# 리스크 지수 : 0.26이고
# 수익률 지수 : 0.33입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 0% 와 기아차 종목 100% 의 비중입니다.
# 리스크 지수 : 0.29이고
# 수익률 지수 : 0.47입니다
# 현대모비스 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 현대모비스 종목 62% 와 삼성SDI 종목 38% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.52입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 현대모비스 종목 26% 와 삼성SDI 종목 74% 의 비중입니다.
# 리스크 지수 : 0.31이고
# 수익률 지수 : 0.88입니다
# 셀트리온 종목과  LG화학 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 셀트리온 종목 41% 와 LG화학 종목 59% 의 비중입니다.
# 리스크 지수 : 0.28이고
# 수익률 지수 : 0.78입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 셀트리온 종목 27% 와 LG화학 종목 73% 의 비중입니다.
# 리스크 지수 : 0.3이고
# 수익률 지수 : 0.85입니다
# 셀트리온 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 셀트리온 종목 29% 와 LG생활건강 종목 71% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.37입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 셀트리온 종목 38% 와 LG생활건강 종목 62% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.38입니다
# 셀트리온 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 셀트리온 종목 17% 와 SK텔레콤 종목 83% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.16입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 셀트리온 종목 35% 와 SK텔레콤 종목 65% 의 비중입니다.
# 리스크 지수 : 0.12이고
# 수익률 지수 : 0.23입니다
# 셀트리온 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 셀트리온 종목 34% 와 기아차 종목 66% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.48입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 셀트리온 종목 34% 와 기아차 종목 66% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.48입니다
# 셀트리온 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 셀트리온 종목 44% 와 삼성SDI 종목 56% 의 비중입니다.
# 리스크 지수 : 0.3이고
# 수익률 지수 : 0.85입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 셀트리온 종목 27% 와 삼성SDI 종목 73% 의 비중입니다.
# 리스크 지수 : 0.32이고
# 수익률 지수 : 0.96입니다
# LG화학 종목과  LG생활건강 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG화학 종목 36% 와 LG생활건강 종목 64% 의 비중입니다.
# 리스크 지수 : 0.2이고
# 수익률 지수 : 0.56입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG화학 종목 57% 와 LG생활건강 종목 43% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.71입니다
# LG화학 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG화학 종목 15% 와 SK텔레콤 종목 85% 의 비중입니다.
# 리스크 지수 : 0.11이고
# 수익률 지수 : 0.23입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG화학 종목 47% 와 SK텔레콤 종목 53% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.52입니다
# LG화학 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG화학 종목 39% 와 기아차 종목 61% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.68입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG화학 종목 54% 와 기아차 종목 46% 의 비중입니다.
# 리스크 지수 : 0.23이고
# 수익률 지수 : 0.76입니다
# LG화학 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG화학 종목 58% 와 삼성SDI 종목 42% 의 비중입니다.
# 리스크 지수 : 0.36이고
# 수익률 지수 : 1.05입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG화학 종목 46% 와 삼성SDI 종목 54% 의 비중입니다.
# 리스크 지수 : 0.36이고
# 수익률 지수 : 1.07입니다
# LG생활건강 종목과  SK텔레콤 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG생활건강 종목 26% 와 SK텔레콤 종목 74% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.15입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG생활건강 종목 46% 와 SK텔레콤 종목 54% 의 비중입니다.
# 리스크 지수 : 0.11이고
# 수익률 지수 : 0.19입니다
# LG생활건강 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG생활건강 종목 52% 와 기아차 종목 48% 의 비중입니다.
# 리스크 지수 : 0.17이고
# 수익률 지수 : 0.39입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG생활건강 종목 44% 와 기아차 종목 56% 의 비중입니다.
# 리스크 지수 : 0.18이고
# 수익률 지수 : 0.4입니다
# LG생활건강 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : LG생활건강 종목 66% 와 삼성SDI 종목 34% 의 비중입니다.
# 리스크 지수 : 0.21이고
# 수익률 지수 : 0.59입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : LG생활건강 종목 41% 와 삼성SDI 종목 59% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.8입니다
# SK텔레콤 종목과  기아차 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK텔레콤 종목 77% 와 기아차 종목 23% 의 비중입니다.
# 리스크 지수 : 0.1이고
# 수익률 지수 : 0.17입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK텔레콤 종목 48% 와 기아차 종목 52% 의 비중입니다.
# 리스크 지수 : 0.13이고
# 수익률 지수 : 0.28입니다
# SK텔레콤 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : SK텔레콤 종목 83% 와 삼성SDI 종목 17% 의 비중입니다.
# 리스크 지수 : 0.11이고
# 수익률 지수 : 0.25입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : SK텔레콤 종목 53% 와 삼성SDI 종목 47% 의 비중입니다.
# 리스크 지수 : 0.15이고
# 수익률 지수 : 0.57입니다
# 기아차 종목과  삼성SDI 종목을 섞었을 경우
# 리스크가 가장 낮은 포트폴리오 비중은 : 기아차 종목 63% 와 삼성SDI 종목 37% 의 비중입니다.
# 리스크 지수 : 0.22이고
# 수익률 지수 : 0.72입니다
#
# 리스크 대비 수익률이 가장 높은 포트폴리오의 비중은 : 기아차 종목 45% 와 삼성SDI 종목 55% 의 비중입니다.
# 리스크 지수 : 0.24이고
# 수익률 지수 : 0.84입니다

# %%
topRank = list(filter(None,topRank)) # TopRank 중 수익률이 음수였던 것들(None)을 제거함

# %%
ranking = pd.DataFrame(topRank) # 데이터프레임 생성

# %%
ranking.head()
# Out:
#       0         1         2         3   4   5
# 0  삼성전자    SK하이닉스  0.173427  0.179458  98  98
# 1  삼성전자     NAVER  0.140193  0.630029  67  37
# 2  삼성전자  삼성바이오로직스  0.154175  0.530911  81  56
# 3  삼성전자       현대차  0.153213  0.211229  72  61
# 4  삼성전자     현대모비스  0.154955  0.173584  73  78

# %%
ranking.columns = ['종목A','종목B','최저위험','저위험고수익','최저위험 종목A 비중(%)','저위험고수익 종목A 비중(%)']

# %%
ranking['최저위험'] = round(ranking['최저위험'] * 100 , 2)
ranking['저위험고수익'] = round(ranking['저위험고수익'] * 100,2)

# %%
ranking.head()
# Out:
#     종목A       종목B   최저위험  저위험고수익  최저위험 종목A 비중(%)  저위험고수익 종목A 비중(%)
# 0  삼성전자    SK하이닉스  17.34   17.95              98                98
# 1  삼성전자     NAVER  14.02   63.00              67                37
# 2  삼성전자  삼성바이오로직스  15.42   53.09              81                56
# 3  삼성전자       현대차  15.32   21.12              72                61
# 4  삼성전자     현대모비스  15.50   17.36              73                78

# %%
riskRanking = ranking.drop(['저위험고수익 종목A 비중(%)'],axis=1,)

# %%
riskRanking['최저위험 종목B 비중(%)'] = (100 - riskRanking['최저위험 종목A 비중(%)'])

# %%
riskRanking = riskRanking.sort_values(by='최저위험') # 최저위험 순위로 정렬

# %%
riskRanking.head(10)
# Out:
#          종목A    종목B   최저위험  저위험고수익  최저위험 종목A 비중(%)  최저위험 종목B 비중(%)
# 8       삼성전자  SK텔레콤   8.59   13.33              37              63
# 27     NAVER  SK텔레콤   9.47   51.08              25              75
# 60    LG생활건강  SK텔레콤   9.51   19.14              26              74
# 18    SK하이닉스  SK텔레콤   9.61    9.99              23              77
# 53      셀트리온  SK텔레콤   9.83   23.00              17              83
# 63     SK텔레콤    기아차  10.36   28.39              77              23
# 35  삼성바이오로직스  SK텔레콤  10.43   43.90              14              86
# 42       현대차  SK텔레콤  10.49   15.82              20              80
# 64     SK텔레콤  삼성SDI  10.65   57.22              83              17
# 48     현대모비스  SK텔레콤  10.69   10.36              18              82

# %%
closePrice.SK텔레콤.plot(figsize=(8, 5), grid=True)
plt.show()

# %%
closePrice.한국전력.plot(figsize=(8, 5), grid=True)
plt.show()

# %%
changeRanking = ranking.drop(['최저위험 종목A 비중(%)'],axis=1)

# %%
changeRanking['저위험고시익 종목B 비중(%)'] = (100 - changeRanking['저위험고수익 종목A 비중(%)'])

# %%
changeRanking = changeRanking.sort_values(by='저위험고수익',ascending=False) # 저위험고수익으로 정렬

# %%
changeRanking.head(10)
# Out:
#          종목A       종목B   최저위험  저위험고수익  저위험고수익 종목A 비중(%)  저위험고시익 종목B 비중(%)
# 37  삼성바이오로직스     삼성SDI  32.10  108.95                37                63
# 59      LG화학     삼성SDI  35.65  107.29                46                54
# 29     NAVER     삼성SDI  21.90  100.71                57                43
# 33  삼성바이오로직스      LG화학  29.33   99.22                38                62
# 55      셀트리온     삼성SDI  30.30   96.33                27                73
# 25     NAVER      LG화학  21.77   94.03                58                42
# 21     NAVER  삼성바이오로직스  22.87   93.57                66                34
# 20    SK하이닉스     삼성SDI  26.02   93.49                20                80
# 50     현대모비스     삼성SDI  24.45   87.76                26                74
# 51      셀트리온      LG화학  28.33   85.02                27                73

# %%
closePrice.삼성SDI.plot(figsize=(8, 5), grid=True)
plt.show()

# %% [markdown]
# # Keras를 활용한 주가 예측

# %%
import warnings
warnings.filterwarnings("ignore")

import scipy as sp
from scipy import stats # statistics
from mpl_toolkits.mplot3d import Axes3D, axes3d
from matplotlib.colors import ListedColormap

from sklearn.datasets import make_blobs #random 한 데이터 묶음을 만들어 줌.
from sklearn.model_selection import train_test_split
from sklearn import datasets, preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM
import datetime

# %% [markdown]
# #### RNN의 LSTM을 사용하려는 이유는 주가 데이터가 순서가 있는 시계열(Time-series) 데이터이기 때문입니다.

# %%
simbol = '035420' # NAVER
startDate = '20021029' # 시작날짜
nowDate = datetime.datetime.now()

# %%
#데이터 전처리
df_KOSPI_price_naver = fdr.DataReader(simbol, startDate,nowDate)
df_KOSPI_price_naver = df_KOSPI_price_naver.reset_index() # 인덱스( Date 위로 올리기)
df_KOSPI_price_naver.rename(columns = {'Date':'일자','Open':'시가','High':'고가','Low':'저가','Close':'종가','Volume':'거래량','Change':'수익률'}, inplace=True)
df_KOSPI_price_naver = df_KOSPI_price_naver.dropna(axis=0) # 결측치제거
df_KOSPI_price_naver
# Out:
#              일자      시가      고가      저가      종가      거래량       수익률
# 1    2002-10-30    8244    8244    8152    8245   853638  0.119332
# 2    2002-10-31    8369    8570    7641    7835  1320880 -0.049727
# 3    2002-11-01    8036    8287    7065    7349   750761 -0.062029
# 4    2002-11-04    7281    7331    6804    6981   692165 -0.050075
# 5    2002-11-05    6946    7315    6946    6973   627360 -0.001146
# ...         ...     ...     ...     ...     ...      ...       ...
# 4396 2020-08-05  312000  314500  306500  313500   809939  0.008039
# 4397 2020-08-06  313000  322000  310500  322000  1032045  0.027113
# 4398 2020-08-07  324500  325500  312000  314000  1063254 -0.024845
# 4399 2020-08-10  308500  314500  303500  313500   968592 -0.001592
# 4400 2020-08-11  311000  314500  307500  311500   660233 -0.006380
#
# [4400 rows x 7 columns]

# %% [markdown]
# 2002 년 10월 30일 부터 오늘까지 주식장이 열린 날이 4399일이다.

# %%
closeMin = df_KOSPI_price_naver['종가'].min()

# %%
closeMax = df_KOSPI_price_naver['종가'].max()

# %% [markdown]
# 정규화를 하기전에 종가의 최소값과 최대값을 미리 저장해둔다. 추 후 정규화된 값을 다시 복구하기 위함.

# %%
# df_KOSPI_price_naver 정규화

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols = ['시가', '고가', '저가', '종가', '거래량','수익률']
df_KOSPI_price_naver_scaled = scaler.fit_transform(df_KOSPI_price_naver[scale_cols])

df_KOSPI_price_naver_scaled = pd.DataFrame(df_KOSPI_price_naver_scaled)
df_KOSPI_price_naver_scaled.columns = scale_cols
df_KOSPI_price_naver_scaled.head()
# Out:
#          시가        고가        저가        종가       거래량       수익률
# 0  0.025405  0.025327  0.026128  0.006705  0.160927  0.967306
# 1  0.025790  0.026329  0.024490  0.005407  0.249010  0.760185
# 2  0.024764  0.025459  0.022644  0.003869  0.141532  0.745113
# 3  0.022438  0.022522  0.021808  0.002704  0.130486  0.759759
# 4  0.021405  0.022473  0.022263  0.002678  0.118269  0.819704

# %% [markdown]
# 정규화를 하는 이유는 딥러닝의 예측을 더 쉽고 정확하게 하기 위해서

# %%
# Train, Test set 분리

TEST_SIZE = 200 

train = df_KOSPI_price_naver_scaled[:-TEST_SIZE] # 마지막 200개 데이터 이전 것
test = df_KOSPI_price_naver_scaled[-TEST_SIZE:] # 마지막 200개 데이터

# %%
# window_size 는 모델링이후에 예측할때 한 묶음당 갯 수

def make_dataset(data, label, window_size = 20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
feature_cols = ['시가', '고가', '저가', '거래량','수익률']
label_cols = ['종가']

train_feature = train[feature_cols]
train_label = train[label_cols]
test_feature = test[feature_cols]
test_label = test[label_cols]

# train dataset
train_feature, train_label = make_dataset(train_feature, train_label, 20)

# train, validation set 생성
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.3)

x_train.shape, x_valid.shape
# Out:
# ((2926, 20, 5), (1254, 20, 5))

# %%
# test dataset 생성

test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((180, 20, 5), (180, 1))

# %%
model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\11\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = 'checkpoint-epoch-batch-trial-001.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# WARNING:tensorflow:From C:\Users\11\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2926 samples, validate on 1254 samples
# WARNING:tensorflow:From C:\Users\11\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 00001: val_loss improved from inf to 0.00055, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 3s 1ms/sample - loss: 0.0131 - val_loss: 5.4936e-04
# Epoch 2/200
# 2880/2926 [============================>.] - ETA: 0s - loss: 7.2354e-04
# Epoch 00002: val_loss improved from 0.00055 to 0.00044, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 673us/sample - loss: 7.1462e-04 - val_loss: 4.3655e-04
# Epoch 3/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 6.5668e-04
# Epoch 00003: val_loss improved from 0.00044 to 0.00041, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 674us/sample - loss: 6.5122e-04 - val_loss: 4.1079e-04
# Epoch 4/200
# 2880/2926 [============================>.] - ETA: 0s - loss: 5.9931e-04
# Epoch 00004: val_loss improved from 0.00041 to 0.00040, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 673us/sample - loss: 6.1336e-04 - val_loss: 3.9769e-04
# Epoch 5/200
# 2832/2926 [============================>.] - ETA: 0s - loss: 5.8400e-04
# Epoch 00005: val_loss improved from 0.00040 to 0.00039, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 684us/sample - loss: 5.7431e-04 - val_loss: 3.8543e-04
# Epoch 6/200
# 2880/2926 [============================>.] - ETA: 0s - loss: 4.9914e-04
# Epoch 00006: val_loss improved from 0.00039 to 0.00033, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 674us/sample - loss: 4.9467e-04 - val_loss: 3.2685e-04
# Epoch 7/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 3.9274e-04
# Epoch 00007: val_loss improved from 0.00033 to 0.00025, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 674us/sample - loss: 3.9046e-04 - val_loss: 2.5335e-04
# Epoch 8/200
# 2832/2926 [============================>.] - ETA: 0s - loss: 3.0129e-04
# Epoch 00008: val_loss improved from 0.00025 to 0.00023, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 673us/sample - loss: 2.9611e-04 - val_loss: 2.2913e-04
# Epoch 9/200
# 2880/2926 [============================>.] - ETA: 0s - loss: 2.4736e-04
# Epoch 00009: val_loss did not improve from 0.00023
# 2926/2926 [==============================] - 2s 675us/sample - loss: 2.4705e-04 - val_loss: 2.3221e-04
# Epoch 10/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 2.4570e-04
# Epoch 00010: val_loss improved from 0.00023 to 0.00020, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 673us/sample - loss: 2.4641e-04 - val_loss: 1.9737e-04
# Epoch 11/200
# 2832/2926 [============================>.] - ETA: 0s - loss: 2.3505e-04
# Epoch 00011: val_loss improved from 0.00020 to 0.00019, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 679us/sample - loss: 2.3340e-04 - val_loss: 1.9436e-04
# Epoch 12/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 2.1033e-04
# Epoch 00012: val_loss did not improve from 0.00019
# 2926/2926 [==============================] - 2s 669us/sample - loss: 2.1053e-04 - val_loss: 2.0938e-04
# Epoch 13/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 2.0692e-04
# Epoch 00013: val_loss did not improve from 0.00019
# 2926/2926 [==============================] - 2s 673us/sample - loss: 2.0647e-04 - val_loss: 1.9611e-04
# Epoch 14/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 2.0573e-04
# Epoch 00014: val_loss improved from 0.00019 to 0.00015, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 673us/sample - loss: 2.0422e-04 - val_loss: 1.5418e-04
# Epoch 15/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 2.0595e-04
# Epoch 00015: val_loss did not improve from 0.00015
# 2926/2926 [==============================] - 2s 674us/sample - loss: 2.0531e-04 - val_loss: 1.5636e-04
# Epoch 16/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 2.0229e-04
# Epoch 00016: val_loss did not improve from 0.00015
# 2926/2926 [==============================] - 2s 668us/sample - loss: 2.0148e-04 - val_loss: 1.6745e-04
# Epoch 17/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 1.9115e-04
# Epoch 00017: val_loss did not improve from 0.00015
# 2926/2926 [==============================] - 2s 674us/sample - loss: 1.9124e-04 - val_loss: 1.8065e-04
# Epoch 18/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 1.8640e-04
# Epoch 00018: val_loss improved from 0.00015 to 0.00014, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 672us/sample - loss: 1.8581e-04 - val_loss: 1.4463e-04
# Epoch 19/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 1.9286e-04
# Epoch 00019: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 669us/sample - loss: 1.9183e-04 - val_loss: 1.5020e-04
# Epoch 20/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 1.8328e-04
# Epoch 00020: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 668us/sample - loss: 1.8034e-04 - val_loss: 1.6168e-04
# Epoch 21/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 1.8802e-04
# Epoch 00021: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 674us/sample - loss: 1.8749e-04 - val_loss: 1.9054e-04
# Epoch 22/200
# 2832/2926 [============================>.] - ETA: 0s - loss: 1.8990e-04
# Epoch 00022: val_loss improved from 0.00014 to 0.00014, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 672us/sample - loss: 1.8741e-04 - val_loss: 1.3996e-04
# Epoch 23/200
# 2864/2926 [============================>.] - ETA: 0s - loss: 1.7498e-04
# Epoch 00023: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 668us/sample - loss: 1.7725e-04 - val_loss: 1.4832e-04
# Epoch 24/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 1.6935e-04
# Epoch 00024: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 685us/sample - loss: 1.6715e-04 - val_loss: 1.7589e-04
# Epoch 25/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 1.6906e-04
# Epoch 00025: val_loss did not improve from 0.00014
# 2926/2926 [==============================] - 2s 679us/sample - loss: 1.6852e-04 - val_loss: 1.4864e-04
# Epoch 26/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 1.6779e-04
# Epoch 00026: val_loss improved from 0.00014 to 0.00013, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 685us/sample - loss: 1.6727e-04 - val_loss: 1.3326e-04
# Epoch 27/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 1.6366e-04
# Epoch 00027: val_loss did not improve from 0.00013
# 2926/2926 [==============================] - 2s 704us/sample - loss: 1.6272e-04 - val_loss: 1.4790e-04
# Epoch 28/200
# 2848/2926 [============================>.] - ETA: 0s - loss: 1.6237e-04
# Epoch 00028: val_loss did not improve from 0.00013
# 2926/2926 [==============================] - 2s 671us/sample - loss: 1.6037e-04 - val_loss: 1.4089e-04
# Epoch 29/200
# 2864/2926 [============================>.] - ETA: 0s - loss: 1.6404e-04
# Epoch 00029: val_loss did not improve from 0.00013
# 2926/2926 [==============================] - 2s 668us/sample - loss: 1.6207e-04 - val_loss: 1.4089e-04
# Epoch 30/200
# 2864/2926 [============================>.] - ETA: 0s - loss: 1.5352e-04
# Epoch 00030: val_loss did not improve from 0.00013
# 2926/2926 [==============================] - 2s 667us/sample - loss: 1.5465e-04 - val_loss: 1.5669e-04
# Epoch 31/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 1.6840e-04
# Epoch 00031: val_loss improved from 0.00013 to 0.00012, saving model to checkpoint-epoch-batch-trial-001.h5
# 2926/2926 [==============================] - 2s 668us/sample - loss: 1.6850e-04 - val_loss: 1.2399e-04
# Epoch 32/200
# 2912/2926 [============================>.] - ETA: 0s - loss: 1.5588e-04
# Epoch 00032: val_loss did not improve from 0.00012
# 2926/2926 [==============================] - 2s 674us/sample - loss: 1.5528e-04 - val_loss: 1.4467e-04
# Epoch 33/200
# 2832/2926 [============================>.] - ETA: 0s - loss: 1.6572e-04
# Epoch 00033: val_loss did not improve from 0.00012
# 2926/2926 [==============================] - 2s 672us/sample - loss: 1.6418e-04 - val_loss: 1.8485e-04
# Epoch 34/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 1.5878e-04
# Epoch 00034: val_loss did not improve from 0.00012
# 2926/2926 [==============================] - 2s 669us/sample - loss: 1.5770e-04 - val_loss: 1.6074e-04
# Epoch 35/200
# 2880/2926 [============================>.] - ETA: 0s - loss: 1.4689e-04
# Epoch 00035: val_loss did not improve from 0.00012
# 2926/2926 [==============================] - 2s 673us/sample - loss: 1.4817e-04 - val_loss: 1.4042e-04
# Epoch 36/200
# 2896/2926 [============================>.] - ETA: 0s - loss: 1.6293e-04
# Epoch 00036: val_loss did not improve from 0.00012
# 2926/2926 [==============================] - 2s 673us/sample - loss: 1.6507e-04 - val_loss: 2.1524e-04

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_feature)

# %%
predY = (closeMax - closeMin) * pred + closeMin

# %%
testY = df_KOSPI_price_naver['종가'][-180:].values

# %%
plt.figure(figsize=(12, 9))
plt.plot(testY, label='actual')
plt.plot(predY, label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# # 다 필요없고 그래서 내일 종가 얼만데?

# %%
naverClosePrice = predY[-1][0]

# %%
naverClosePrice
# Out:
# 318369.5123960376

# %%
Message=('오늘의 네이버 예측 종가는 {}원 입니다.'.format(round(naverClosePrice)))
Message=str(Message)
print(Message)
# Out:
# 오늘의 네이버 예측 종가는 318370.0원 입니다.

# %%
import smtplib
from email.mime.text import MIMEText

def sendMail(sender, receiver, msg):
    smtp = smtplib.SMTP_SSL('smtp.gmail.com', 465) #메일 제공사마다 다름.
    smtp.login('kimamugae6jo@gmail.com', 'ihvqaddkjnoatjxk') # 지메일 "앱 비밀번호" 를 입력해주세요. 개인 메일 계정
    msg = MIMEText(Message)
    msg['Subject'] = '오늘의 예측 종가를 알려드립니다' #메일의 제목
    smtp.sendmail('kimamugae6jo@gmail.com', receiver, msg.as_string())
    smtp.quit()

# %%
sendMail('kimamugae6jo@gmail.com', 'alswhddh3@gmail.com', Message)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
